# %% [markdown]
# # Dataframes 2

# %%
import pandas as pd

# %%
df = pd.read_csv("data/employees.csv")
df.head()
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 1     Thomas    Male  3/31/1996         6:53 AM   61933    4.170
# 2      Maria  Female  4/23/1993        11:17 AM  130590   11.858
# 3      Jerry    Male   3/4/2005         1:00 PM  138705    9.340
# 4      Larry    Male  1/24/1998         4:47 PM  101004    1.389
#
#   Senior Management             Team
# 0              True        Marketing
# 1              True              NaN
# 2             False          Finance
# 3              True          Finance
# 4              True  Client Services

# %% [markdown]
# look at the data using `df.info()` method
# * Note some cols have missing values
# * Note Gender should be a category dtype
# * Note the two cols that should be changed to date dtype
# * Note senior management col should be a boolean dtype

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
# First Name           933 non-null object
# Gender               855 non-null object
# Start Date           1000 non-null object
# Last Login Time      1000 non-null object
# Salary               1000 non-null int64
# Bonus %              1000 non-null float64
# Senior Management    933 non-null object
# Team                 957 non-null object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 62.6+ KB

# %%
df["Start Date"].head()
# Out:
# 0     8/6/1993
# 1    3/31/1996
# 2    4/23/1993
# 3     3/4/2005
# 4    1/24/1998
# Name: Start Date, dtype: object

# %%
df["Start Date"] = pd.to_datetime(df["Start Date"])

# %%
df.head()
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06        12:42 PM   97308    6.945
# 1     Thomas    Male 1996-03-31         6:53 AM   61933    4.170
# 2      Maria  Female 1993-04-23        11:17 AM  130590   11.858
# 3      Jerry    Male 2005-03-04         1:00 PM  138705    9.340
# 4      Larry    Male 1998-01-24         4:47 PM  101004    1.389
#
#   Senior Management             Team
# 0              True        Marketing
# 1              True              NaN
# 2             False          Finance
# 3              True          Finance
# 4              True  Client Services

# %%
pd.to_datetime(df["Last Login Time"])    # note date is autofilled with todays date
# Out:
# 0     2018-03-10 12:42:00
# 1     2018-03-10 06:53:00
# 2     2018-03-10 11:17:00
# 3     2018-03-10 13:00:00
# 4     2018-03-10 16:47:00
# 5     2018-03-10 01:35:00
# 6     2018-03-10 16:20:00
# 7     2018-03-10 10:43:00
# 8     2018-03-10 06:29:00
# 9     2018-03-10 06:51:00
# 10    2018-03-10 09:01:00
# 11    2018-03-10 15:19:00
# 12    2018-03-10 01:08:00
# 13    2018-03-10 23:40:00
# 14    2018-03-10 07:13:00
# 15    2018-03-10 06:09:00
# 16    2018-03-10 05:56:00
# 17    2018-03-10 19:45:00
# 18    2018-03-10 10:27:00
# 19    2018-03-10 03:48:00
# 20    2018-03-10 19:18:00
# 21    2018-03-10 02:12:00
# 22    2018-03-10 01:58:00
# 23    2018-03-10 16:19:00
# 24    2018-03-10 22:08:00
# 25    2018-03-10 01:12:00
# 26    2018-03-10 07:45:00
# 27    2018-03-10 18:58:00
# 28    2018-03-10 18:30:00
# 29    2018-03-10 22:06:00
#               ...
# 970   2018-03-10 20:54:00
# 971   2018-03-10 02:01:00
# 972   2018-03-10 14:49:00
# 973   2018-03-10 23:08:00
# 974   2018-03-10 18:31:00
# ...

# %%
df["Last Login Time"] = pd.to_datetime(df["Last Login Time"])

# %%
df.head()
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2018-03-10 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2018-03-10 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2018-03-10 11:17:00  130590   11.858
# 3      Jerry    Male 2005-03-04 2018-03-10 13:00:00  138705    9.340
# 4      Larry    Male 1998-01-24 2018-03-10 16:47:00  101004    1.389
#
#   Senior Management             Team
# 0              True        Marketing
# 1              True              NaN
# 2             False          Finance
# 3              True          Finance
# 4              True  Client Services

# %%
df["Senior Management"] = df["Senior Management"].astype(bool)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
# First Name           933 non-null object
# Gender               855 non-null object
# Start Date           1000 non-null datetime64[ns]
# Last Login Time      1000 non-null datetime64[ns]
# Salary               1000 non-null int64
# Bonus %              1000 non-null float64
# Senior Management    1000 non-null bool
# Team                 957 non-null object
# dtypes: bool(1), datetime64[ns](2), float64(1), int64(1), object(3)
# memory usage: 55.7+ KB

# %%
df["Gender"] = df["Gender"].astype("category")

# %%
df.info()    # note memory usage down
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
# First Name           933 non-null object
# Gender               855 non-null category
# Start Date           1000 non-null datetime64[ns]
# Last Login Time      1000 non-null datetime64[ns]
# Salary               1000 non-null int64
# Bonus %              1000 non-null float64
# Senior Management    1000 non-null bool
# Team                 957 non-null object
# dtypes: bool(1), category(1), datetime64[ns](2), float64(1), int64(1), object(2)
# memory usage: 49.0+ KB

# %% [markdown]
# restart with consolidated code
#
# `df = pd.read_csv("data/employees.csv")
# df["Start Date"] = pd.to_datetime(df["Start Date"])
# df["Last Login Time"] = pd.to_datetime(df["Last Login Time"])
# df["Senior Management"] = df["Senior Management"].astype(bool)
# df["Gender"] = df["Gender"].astype("category")
# df.head()`

# %%
df = pd.read_csv("data/employees.csv")
df["Start Date"] = pd.to_datetime(df["Start Date"])
df["Last Login Time"] = pd.to_datetime(df["Last Login Time"])
df["Senior Management"] = df["Senior Management"].astype(bool)
df["Gender"] = df["Gender"].astype("category")
df.head()
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2018-03-10 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2018-03-10 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2018-03-10 11:17:00  130590   11.858
# 3      Jerry    Male 2005-03-04 2018-03-10 13:00:00  138705    9.340
# 4      Larry    Male 1998-01-24 2018-03-10 16:47:00  101004    1.389
#
#    Senior Management             Team
# 0               True        Marketing
# 1               True              NaN
# 2              False          Finance
# 3               True          Finance
# 4               True  Client Services

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
# First Name           933 non-null object
# Gender               855 non-null category
# Start Date           1000 non-null datetime64[ns]
# Last Login Time      1000 non-null datetime64[ns]
# Salary               1000 non-null int64
# Bonus %              1000 non-null float64
# Senior Management    1000 non-null bool
# Team                 957 non-null object
# dtypes: bool(1), category(1), datetime64[ns](2), float64(1), int64(1), object(2)
# memory usage: 49.0+ KB

# %%
49.0/62.6
# more than 20% reduction in memory usage of original data types
# Out:
# 0.7827476038338658

# %%
# alternate method - first, note the default info()
df = pd.read_csv("data/employees.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
# First Name           933 non-null object
# Gender               855 non-null object
# Start Date           1000 non-null object
# Last Login Time      1000 non-null object
# Salary               1000 non-null int64
# Bonus %              1000 non-null float64
# Senior Management    933 non-null object
# Team                 957 non-null object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 62.6+ KB

# %%
# now use the parse_dates parameter to enter date column or columns using a python list

# %%
df = pd.read_csv("data/employees.csv", parse_dates=["Start Date","Last Login Time"])
# no need for to_datetime() methods
df["Senior Management"] = df["Senior Management"].astype(bool)
df["Gender"] = df["Gender"].astype("category")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
# First Name           933 non-null object
# Gender               855 non-null category
# Start Date           1000 non-null datetime64[ns]
# Last Login Time      1000 non-null datetime64[ns]
# Salary               1000 non-null int64
# Bonus %              1000 non-null float64
# Senior Management    1000 non-null bool
# Team                 957 non-null object
# dtypes: bool(1), category(1), datetime64[ns](2), float64(1), int64(1), object(2)
# memory usage: 49.0+ KB

# %%
# filtering using a condition - extract rows that meet a condition

# %%
df.head()
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2018-03-10 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2018-03-10 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2018-03-10 11:17:00  130590   11.858
# 3      Jerry    Male 2005-03-04 2018-03-10 13:00:00  138705    9.340
# 4      Larry    Male 1998-01-24 2018-03-10 16:47:00  101004    1.389
#
#    Senior Management             Team
# 0               True        Marketing
# 1               True              NaN
# 2              False          Finance
# 3               True          Finance
# 4               True  Client Services

# %%
df['Gender']

# %%
df["Gender"] == "Male"    # returns a series of booleans 
# double equals is a comparison operator
# Out:
# 0       True
# 1       True
# 2      False
# 3       True
# 4       True
# 5       True
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12      True
# 13      True
# 14     False
# 15     False
# 16      True
# 17      True
# 18     False
# 19     False
# 20     False
# 21      True
# 22     False
# 23      True
# 24      True
# 25      True
# 26      True
# 27     False
# 28      True
# 29      True
#        ...
# 970    False
# 971     True
# 972    False
# 973     True
# 974     True
# 975    False
# 976    False
# 977    False
# 978     True
# 979     True
# 980    False
# 981     True
# 982    False
# 983     True
# 984    False
# 985    False
# 986    False
# 987    False
# 988    False
# 989    False
# 990    False
# 991    False
# 992     True
# 993    False
# 994     True
# 995    False
# 996     True
# 997     True
# 998     True
# 999     True
# Name: Gender, Length: 1000, dtype: bool

# %%
df[df["Gender"] == "Male"]
# Out:
#     First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas   Male 1993-08-06 2018-03-10 12:42:00   97308    6.945
# 1       Thomas   Male 1996-03-31 2018-03-10 06:53:00   61933    4.170
# 3        Jerry   Male 2005-03-04 2018-03-10 13:00:00  138705    9.340
# 4        Larry   Male 1998-01-24 2018-03-10 16:47:00  101004    1.389
# 5       Dennis   Male 1987-04-18 2018-03-10 01:35:00  115163   10.125
# 12     Brandon   Male 1980-12-01 2018-03-10 01:08:00  112807   17.492
# 13        Gary   Male 2008-01-27 2018-03-10 23:40:00  109831    5.831
# 16      Jeremy   Male 2010-09-21 2018-03-10 05:56:00   90370    7.369
# 17       Shawn   Male 1986-12-07 2018-03-10 19:45:00  111737    6.414
# 21     Matthew   Male 1995-09-05 2018-03-10 02:12:00  100612   13.645
# 23         NaN   Male 2012-06-14 2018-03-10 16:19:00  125792    5.042
# 24        John   Male 1992-07-01 2018-03-10 22:08:00   97950   13.873
# ...

# %%
# display finance people
df[df["Team"] == "Finance"] # pass boolean series back to the df
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 2        Maria  Female 1993-04-23 2018-03-10 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2018-03-10 13:00:00  138705    9.340
# 7          NaN  Female 2015-07-20 2018-03-10 10:43:00   45906   11.598
# 14    Kimberly  Female 1999-01-14 2018-03-10 07:13:00   41426   14.543
# 46       Bruce    Male 2009-11-28 2018-03-10 22:47:00  114796    6.796
# 53        Alan     NaN 2014-03-03 2018-03-10 13:28:00   40341   17.578
# 56        Carl    Male 2006-05-03 2018-03-10 17:55:00  130276   16.084
# 67      Rachel  Female 1999-08-16 2018-03-10 06:53:00   51178    9.735
# 68        Jose    Male 2004-10-30 2018-03-10 13:39:00   84834   14.330
# 69       Irene     NaN 2015-07-14 2018-03-10 16:31:00  100863    4.382
# 83       Shawn    Male 2005-09-23 2018-03-10 02:55:00  148115    6.539
# 84       Doris  Female 2004-08-20 2018-03-10 05:51:00   83072    7.511
# ...

# %%
# alt method

# %%
mask = df["Team"] == "Finance"

# %%
type(mask)
# Out:
# pandas.core.series.Series

# %%
df[mask].head(10)
# Out:
#    First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 2       Maria  Female 1993-04-23 2018-03-10 11:17:00  130590   11.858
# 3       Jerry    Male 2005-03-04 2018-03-10 13:00:00  138705    9.340
# 7         NaN  Female 2015-07-20 2018-03-10 10:43:00   45906   11.598
# 14   Kimberly  Female 1999-01-14 2018-03-10 07:13:00   41426   14.543
# 46      Bruce    Male 2009-11-28 2018-03-10 22:47:00  114796    6.796
# 53       Alan     NaN 2014-03-03 2018-03-10 13:28:00   40341   17.578
# 56       Carl    Male 2006-05-03 2018-03-10 17:55:00  130276   16.084
# 67     Rachel  Female 1999-08-16 2018-03-10 06:53:00   51178    9.735
# 68       Jose    Male 2004-10-30 2018-03-10 13:39:00   84834   14.330
# 69      Irene     NaN 2015-07-14 2018-03-10 16:31:00  100863    4.382
#
#     Senior Management     Team
# 2               False  Finance
# 3                True  Finance
# 7                True  Finance
# 14               True  Finance
# 46              False  Finance
# ...

# %%
mask = df["Senior Management"] == True
df[mask].head(10)
# Out:
#    First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0     Douglas    Male 1993-08-06 2018-03-10 12:42:00   97308    6.945
# 1      Thomas    Male 1996-03-31 2018-03-10 06:53:00   61933    4.170
# 3       Jerry    Male 2005-03-04 2018-03-10 13:00:00  138705    9.340
# 4       Larry    Male 1998-01-24 2018-03-10 16:47:00  101004    1.389
# 6        Ruby  Female 1987-08-17 2018-03-10 16:20:00   65476   10.012
# 7         NaN  Female 2015-07-20 2018-03-10 10:43:00   45906   11.598
# 8      Angela  Female 2005-11-22 2018-03-10 06:29:00   95570   18.523
# 9     Frances  Female 2002-08-08 2018-03-10 06:51:00  139852    7.524
# 10     Louise  Female 1980-08-12 2018-03-10 09:01:00   63241   15.132
# 11      Julie  Female 1997-10-26 2018-03-10 15:19:00  102508   12.637
#
#     Senior Management                  Team
# 0                True             Marketing
# 1                True                   NaN
# 3                True               Finance
# ...

# %%
# filter based on NOT

# %%
mask = df["Team"] != "Marketing"
df[mask].head(10)
# Out:
#    First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 1      Thomas    Male 1996-03-31 2018-03-10 06:53:00   61933    4.170
# 2       Maria  Female 1993-04-23 2018-03-10 11:17:00  130590   11.858
# 3       Jerry    Male 2005-03-04 2018-03-10 13:00:00  138705    9.340
# 4       Larry    Male 1998-01-24 2018-03-10 16:47:00  101004    1.389
# 5      Dennis    Male 1987-04-18 2018-03-10 01:35:00  115163   10.125
# 6        Ruby  Female 1987-08-17 2018-03-10 16:20:00   65476   10.012
# 7         NaN  Female 2015-07-20 2018-03-10 10:43:00   45906   11.598
# 8      Angela  Female 2005-11-22 2018-03-10 06:29:00   95570   18.523
# 9     Frances  Female 2002-08-08 2018-03-10 06:51:00  139852    7.524
# 10     Louise  Female 1980-08-12 2018-03-10 09:01:00   63241   15.132
#
#     Senior Management                  Team
# 1                True                   NaN
# 2               False               Finance
# 3                True               Finance
# ...

# %%
# salary greater than 100k

# %%
mask = df["Salary"] > 110000
df[mask].head(10)
# Out:
#    First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 2       Maria  Female 1993-04-23 2018-03-10 11:17:00  130590   11.858
# 3       Jerry    Male 2005-03-04 2018-03-10 13:00:00  138705    9.340
# 5      Dennis    Male 1987-04-18 2018-03-10 01:35:00  115163   10.125
# 9     Frances  Female 2002-08-08 2018-03-10 06:51:00  139852    7.524
# 12    Brandon    Male 1980-12-01 2018-03-10 01:08:00  112807   17.492
# 17      Shawn    Male 1986-12-07 2018-03-10 19:45:00  111737    6.414
# 18      Diana  Female 1981-10-23 2018-03-10 10:27:00  132940   19.082
# 23        NaN    Male 2012-06-14 2018-03-10 16:19:00  125792    5.042
# 27      Scott     NaN 1991-07-11 2018-03-10 18:58:00  122367    5.218
# 28      Terry    Male 1981-11-27 2018-03-10 18:30:00  124008   13.464
#
#     Senior Management                  Team
# 2               False               Finance
# 3                True               Finance
# 5               False                 Legal
# ...

# %%
# bonus % less than 1.5

# %%
mask = df["Bonus %"] < 1.5
df[mask].head()
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 4        Larry    Male 1998-01-24 2018-03-10 16:47:00  101004    1.389
# 15     Lillian  Female 2016-06-05 2018-03-10 06:09:00   59414    1.256
# 58     Theresa  Female 2010-04-11 2018-03-10 07:18:00   72670    1.481
# 77     Charles    Male 2004-09-14 2018-03-10 20:13:00  107391    1.260
# 175     Willie    Male 1998-02-17 2018-03-10 20:20:00  146651    1.451
#
#      Senior Management             Team
# 4                 True  Client Services
# 15               False          Product
# 58                True      Engineering
# 77                True        Marketing
# 175               True      Engineering

# %%
# same as 
df[df["Bonus %"] < 1.5].head()
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 4        Larry    Male 1998-01-24 2018-03-10 16:47:00  101004    1.389
# 15     Lillian  Female 2016-06-05 2018-03-10 06:09:00   59414    1.256
# 58     Theresa  Female 2010-04-11 2018-03-10 07:18:00   72670    1.481
# 77     Charles    Male 2004-09-14 2018-03-10 20:13:00  107391    1.260
# 175     Willie    Male 1998-02-17 2018-03-10 20:20:00  146651    1.451
#
#      Senior Management             Team
# 4                 True  Client Services
# 15               False          Product
# 58                True      Engineering
# 77                True        Marketing
# 175               True      Engineering

# %%
# filter based on more than one condition - AND

# %%
# reset 
df = pd.read_csv("data/employees.csv", parse_dates=["Start Date","Last Login Time"])
df["Senior Management"] = df["Senior Management"].astype(bool)
df["Gender"] = df["Gender"].astype("category")
df.head(3)
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2018-03-10 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2018-03-10 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2018-03-10 11:17:00  130590   11.858
#
#    Senior Management       Team
# 0               True  Marketing
# 1               True        NaN
# 2              False    Finance

# %%
# extract males in marketing 
# df["Gender"] == "Male" & df["Team"] == "Marketing"  ## NOPE
mask1 = df["Gender"] == "Male"
mask2 = df["Team"] == "Marketing"
df[mask1 & mask2].head(10)
# Out:
#     First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas   Male 1993-08-06 2018-03-10 12:42:00   97308    6.945
# 21     Matthew   Male 1995-09-05 2018-03-10 02:12:00  100612   13.645
# 26       Craig   Male 2000-02-27 2018-03-10 07:45:00   37598    7.757
# 74      Thomas   Male 1995-06-04 2018-03-10 14:24:00   62096   17.029
# 77     Charles   Male 2004-09-14 2018-03-10 20:13:00  107391    1.260
# 101      Aaron   Male 2012-02-17 2018-03-10 10:20:00   61602   11.849
# 104       John   Male 1989-12-23 2018-03-10 07:01:00   80740   19.305
# 112     Willie   Male 2003-11-27 2018-03-10 06:21:00   64363    4.023
# 119       Paul   Male 2008-06-03 2018-03-10 15:05:00   41054   12.299
# 150       Sean   Male 1996-05-04 2018-03-10 20:59:00  135490   19.934
#
#      Senior Management       Team
# 0                 True  Marketing
# 21               False  Marketing
# 26                True  Marketing
# 74               False  Marketing
# ...

# %%
# OR

# %%
# reset 
df = pd.read_csv("data/employees.csv", parse_dates=["Start Date","Last Login Time"])
df["Senior Management"] = df["Senior Management"].astype(bool)
df["Gender"] = df["Gender"].astype("category")
df.head(3)
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2018-03-10 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2018-03-10 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2018-03-10 11:17:00  130590   11.858
#
#    Senior Management       Team
# 0               True  Marketing
# 1               True        NaN
# 2              False    Finance

# %%
# senior managers before 1990

# %%
mask1 = df["Senior Management"]    # already a bool
mask2 = df["Start Date"] < "1990-01-01"
df[mask1 | mask2].head(10)
# note that Dennis is not Senior management, but he did start before 1/1/1990
# Out:
#    First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0     Douglas    Male 1993-08-06 2018-03-10 12:42:00   97308    6.945
# 1      Thomas    Male 1996-03-31 2018-03-10 06:53:00   61933    4.170
# 3       Jerry    Male 2005-03-04 2018-03-10 13:00:00  138705    9.340
# 4       Larry    Male 1998-01-24 2018-03-10 16:47:00  101004    1.389
# 5      Dennis    Male 1987-04-18 2018-03-10 01:35:00  115163   10.125
# 6        Ruby  Female 1987-08-17 2018-03-10 16:20:00   65476   10.012
# 7         NaN  Female 2015-07-20 2018-03-10 10:43:00   45906   11.598
# 8      Angela  Female 2005-11-22 2018-03-10 06:29:00   95570   18.523
# 9     Frances  Female 2002-08-08 2018-03-10 06:51:00  139852    7.524
# 10     Louise  Female 1980-08-12 2018-03-10 09:01:00   63241   15.132
#
#     Senior Management                  Team
# 0                True             Marketing
# 1                True                   NaN
# 3                True               Finance
# ...

# %% [markdown]
# # .isin() method

# %%
df = pd.read_csv("data/employees.csv", parse_dates=["Start Date","Last Login Time"])
df["Senior Management"] = df["Senior Management"].astype(bool)
df["Gender"] = df["Gender"].astype("category")
df.head(3)
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2018-03-10 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2018-03-10 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2018-03-10 11:17:00  130590   11.858
#
#    Senior Management       Team
# 0               True  Marketing
# 1               True        NaN
# 2              False    Finance

# %%
# extract all rows where Team is Sales, Product, and Legal

# %%
# The brute force method
mask1 = df["Team"] == "Legal"
mask2 = df["Team"] == "Sales"
mask3 = df["Team"] == "Product"
df[mask1 | mask2 | mask3].head()
# Out:
#    First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 5      Dennis    Male 1987-04-18 2018-03-10 01:35:00  115163   10.125
# 6        Ruby  Female 1987-08-17 2018-03-10 16:20:00   65476   10.012
# 11      Julie  Female 1997-10-26 2018-03-10 15:19:00  102508   12.637
# 13       Gary    Male 2008-01-27 2018-03-10 23:40:00  109831    5.831
# 15    Lillian  Female 2016-06-05 2018-03-10 06:09:00   59414    1.256
#
#     Senior Management     Team
# 5               False    Legal
# 6                True  Product
# 11               True    Legal
# 13              False    Sales
# 15              False  Product

# %%
df["Team"].isin(["Legal","Sales","Product"]).head(10)
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5     True
# 6     True
# 7    False
# 8    False
# 9    False
# Name: Team, dtype: bool

# %%
mask = df["Team"].isin(["Marketing","Sales","Product"])
df[mask].head(10)
# Out:
#    First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0     Douglas    Male 1993-08-06 2018-03-10 12:42:00   97308    6.945
# 6        Ruby  Female 1987-08-17 2018-03-10 16:20:00   65476   10.012
# 13       Gary    Male 2008-01-27 2018-03-10 23:40:00  109831    5.831
# 15    Lillian  Female 2016-06-05 2018-03-10 06:09:00   59414    1.256
# 17      Shawn    Male 1986-12-07 2018-03-10 19:45:00  111737    6.414
# 19      Donna  Female 2010-07-22 2018-03-10 03:48:00   81014    1.894
# 21    Matthew    Male 1995-09-05 2018-03-10 02:12:00  100612   13.645
# 26      Craig    Male 2000-02-27 2018-03-10 07:45:00   37598    7.757
# 31      Joyce     NaN 2005-02-20 2018-03-10 14:40:00   88657   12.752
# 35    Theresa  Female 2006-10-10 2018-03-10 01:12:00   85182   16.675
#
#     Senior Management       Team
# 0                True  Marketing
# 6                True    Product
# 13              False      Sales
# 15              False    Product
# ...

# %%
# isnull() and notnull() methods

# %%
# reset 
df = pd.read_csv("data/employees.csv", parse_dates=["Start Date","Last Login Time"])
df["Senior Management"] = df["Senior Management"].astype(bool)
df["Gender"] = df["Gender"].astype("category")
df.head(3)
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2018-03-10 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2018-03-10 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2018-03-10 11:17:00  130590   11.858
#
#    Senior Management       Team
# 0               True  Marketing
# 1               True        NaN
# 2              False    Finance

# %%
# display rows where value for Team is null

# %%
mask = df["Team"].isnull()
mask.head(12)
# Out:
# 0     False
# 1      True
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10     True
# 11    False
# Name: Team, dtype: bool

# %%
df[mask].head()
# Out:
#    First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 1      Thomas    Male 1996-03-31 2018-03-10 06:53:00   61933    4.170
# 10     Louise  Female 1980-08-12 2018-03-10 09:01:00   63241   15.132
# 23        NaN    Male 2012-06-14 2018-03-10 16:19:00  125792    5.042
# 32        NaN    Male 1998-08-21 2018-03-10 14:27:00  122340    6.417
# 91      James     NaN 2005-01-26 2018-03-10 23:00:00  128771    8.309
#
#     Senior Management Team
# 1                True  NaN
# 10               True  NaN
# 23               True  NaN
# 32               True  NaN
# 91              False  NaN

# %%
# extract rows where Gender is not null

# %%
laskdjf = df["Gender"].notnull()
df[laskdjf].head()
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2018-03-10 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2018-03-10 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2018-03-10 11:17:00  130590   11.858
# 3      Jerry    Male 2005-03-04 2018-03-10 13:00:00  138705    9.340
# 4      Larry    Male 1998-01-24 2018-03-10 16:47:00  101004    1.389
#
#    Senior Management             Team
# 0               True        Marketing
# 1               True              NaN
# 2              False          Finance
# 3               True          Finance
# 4               True  Client Services

# %%
# or in one line
df[df["Gender"].notnull()].head()
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2018-03-10 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2018-03-10 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2018-03-10 11:17:00  130590   11.858
# 3      Jerry    Male 2005-03-04 2018-03-10 13:00:00  138705    9.340
# 4      Larry    Male 1998-01-24 2018-03-10 16:47:00  101004    1.389
#
#    Senior Management             Team
# 0               True        Marketing
# 1               True              NaN
# 2              False          Finance
# 3               True          Finance
# 4               True  Client Services

# %%
# between() method - values between a range

# %%
# reset 
df = pd.read_csv("data/employees.csv", parse_dates=["Start Date","Last Login Time"])
df["Senior Management"] = df["Senior Management"].astype(bool)
df["Gender"] = df["Gender"].astype("category")
df.head(3)
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2018-03-10 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2018-03-10 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2018-03-10 11:17:00  130590   11.858
#
#    Senior Management       Team
# 0               True  Marketing
# 1               True        NaN
# 2              False    Finance

# %%
df[df["Salary"].between(60000,70000)].head()
# Out:
#    First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 1      Thomas    Male 1996-03-31 2018-03-10 06:53:00   61933    4.170
# 6        Ruby  Female 1987-08-17 2018-03-10 16:20:00   65476   10.012
# 10     Louise  Female 1980-08-12 2018-03-10 09:01:00   63241   15.132
# 20       Lois     NaN 1995-04-22 2018-03-10 19:18:00   64714    4.934
# 41  Christine     NaN 2015-06-28 2018-03-10 01:08:00   66582   11.308
#
#     Senior Management                  Team
# 1                True                   NaN
# 6                True               Product
# 10               True                   NaN
# 20               True                 Legal
# 41               True  Business Development

# %%
# list employees with bonus between 2% and 5%
df[df["Bonus %"].between(2.0,5.0)].head()
# Out:
#    First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 1      Thomas   Male 1996-03-31 2018-03-10 06:53:00   61933    4.170
# 20       Lois    NaN 1995-04-22 2018-03-10 19:18:00   64714    4.934
# 40    Michael   Male 2008-10-10 2018-03-10 11:25:00   99283    2.665
# 49      Chris    NaN 1980-01-24 2018-03-10 12:13:00  113590    3.055
# 60      Paula    NaN 2005-11-23 2018-03-10 14:01:00   48866    4.271
#
#     Senior Management          Team
# 1                True           NaN
# 20               True         Legal
# 40               True  Distribution
# 49              False         Sales
# 60              False  Distribution

# %%
# date between

# %%
df[df["Start Date"].between("1990-01-01","2000-01-01")].head(10)
# Out:
#    First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0     Douglas    Male 1993-08-06 2018-03-10 12:42:00   97308    6.945
# 1      Thomas    Male 1996-03-31 2018-03-10 06:53:00   61933    4.170
# 2       Maria  Female 1993-04-23 2018-03-10 11:17:00  130590   11.858
# 4       Larry    Male 1998-01-24 2018-03-10 16:47:00  101004    1.389
# 11      Julie  Female 1997-10-26 2018-03-10 15:19:00  102508   12.637
# 14   Kimberly  Female 1999-01-14 2018-03-10 07:13:00   41426   14.543
# 20       Lois     NaN 1995-04-22 2018-03-10 19:18:00   64714    4.934
# 21    Matthew    Male 1995-09-05 2018-03-10 02:12:00  100612   13.645
# 24       John    Male 1992-07-01 2018-03-10 22:08:00   97950   13.873
# 27      Scott     NaN 1991-07-11 2018-03-10 18:58:00  122367    5.218
#
#     Senior Management             Team
# 0                True        Marketing
# 1                True              NaN
# 2               False          Finance
# ...

# %% [markdown]
# # extract duplicates and uniques
#
# with duplicates() method

# %%
# reset 
df = pd.read_csv("data/employees.csv", parse_dates=["Start Date","Last Login Time"])
df["Senior Management"] = df["Senior Management"].astype(bool)
df["Gender"] = df["Gender"].astype("category")
df.head(3)
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2018-03-10 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2018-03-10 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2018-03-10 11:17:00  130590   11.858
#
#    Senior Management       Team
# 0               True  Marketing
# 1               True        NaN
# 2              False    Finance

# %%
# start by sorting 
df.sort_values("First Name", inplace=True)
df.head(10)
# Out:
#     First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 101      Aaron   Male 2012-02-17 2018-03-10 10:20:00   61602   11.849
# 327      Aaron   Male 1994-01-29 2018-03-10 18:48:00   58755    5.097
# 440      Aaron   Male 1990-07-22 2018-03-10 14:53:00   52119   11.343
# 937      Aaron    NaN 1986-01-22 2018-03-10 19:39:00   63126   18.424
# 137       Adam   Male 2011-05-21 2018-03-10 01:45:00   95327   15.120
# 141       Adam   Male 1990-12-24 2018-03-10 20:57:00  110194   14.727
# 302       Adam   Male 2007-07-05 2018-03-10 11:59:00   71276    5.027
# 538       Adam   Male 2010-10-08 2018-03-10 21:53:00   45181    3.491
# 300       Alan   Male 1988-06-26 2018-03-10 03:54:00  111786    3.592
# 53        Alan    NaN 2014-03-03 2018-03-10 13:28:00   40341   17.578
#
#      Senior Management             Team
# 101               True        Marketing
# 327               True        Marketing
# 440               True  Client Services
# ...

# %%
df["First Name"].head(10)
# Out:
# 101    Aaron
# 327    Aaron
# 440    Aaron
# 937    Aaron
# 137     Adam
# 141     Adam
# 302     Adam
# 538     Adam
# 300     Alan
# 53      Alan
# Name: First Name, dtype: object

# %%
# identify duplicate First Names 
df["First Name"].duplicated().head(10)  # by default duplicated(keep="first")
# Out:
# 101    False
# 327     True
# 440     True
# 937     True
# 137    False
# 141     True
# 302     True
# 538     True
# 300    False
# 53      True
# Name: First Name, dtype: bool

# %%
# Note above how the first Aaron, Adam, Alan are not considered a duplicate, but the remaining are duplicates
# to reverse that use ...
df["First Name"].duplicated(keep="last").head(10)
# Note below how the first instance of a value is considered a duplicate, but the last is not
# Out:
# 101     True
# 327     True
# 440     True
# 937    False
# 137     True
# 141     True
# 302     True
# 538    False
# 300     True
# 53      True
# Name: First Name, dtype: bool

# %%
# a condensed version
df.duplicated("First Name", keep = "last").head(10)
# Out:
# 101     True
# 327     True
# 440     True
# 937    False
# 137     True
# 141     True
# 302     True
# 538    False
# 300     True
# 53      True
# dtype: bool

# %%
# now just display ALL duplicates 
df[df["First Name"].duplicated(keep = False)].head(10)
# Out:
#     First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 101      Aaron   Male 2012-02-17 2018-03-10 10:20:00   61602   11.849
# 327      Aaron   Male 1994-01-29 2018-03-10 18:48:00   58755    5.097
# 440      Aaron   Male 1990-07-22 2018-03-10 14:53:00   52119   11.343
# 937      Aaron    NaN 1986-01-22 2018-03-10 19:39:00   63126   18.424
# 137       Adam   Male 2011-05-21 2018-03-10 01:45:00   95327   15.120
# 141       Adam   Male 1990-12-24 2018-03-10 20:57:00  110194   14.727
# 302       Adam   Male 2007-07-05 2018-03-10 11:59:00   71276    5.027
# 538       Adam   Male 2010-10-08 2018-03-10 21:53:00   45181    3.491
# 300       Alan   Male 1988-06-26 2018-03-10 03:54:00  111786    3.592
# 53        Alan    NaN 2014-03-03 2018-03-10 13:28:00   40341   17.578
#
#      Senior Management             Team
# 101               True        Marketing
# 327               True        Marketing
# 440               True  Client Services
# ...

# %%
# display unique names 
# first filter all duplicates 
df["First Name"].duplicated(keep = False)  # filters all duplicates ... but we want the NOT duplicates
# so how to do the reversal ?
# the tilde reverses booleans 
mask = ~df["First Name"].duplicated(keep = False)   # NOTE THE TILDE 
df[mask]  # displays employees with unique first names
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 8       Angela  Female 2005-11-22 2018-03-10 06:29:00   95570   18.523
# 688      Brian    Male 2007-04-07 2018-03-10 22:47:00   93901   17.821
# 190      Carol  Female 1996-03-19 2018-03-10 03:39:00   57783    9.129
# 887      David    Male 2009-12-05 2018-03-10 08:48:00   92242   15.407
# 5       Dennis    Male 1987-04-18 2018-03-10 01:35:00  115163   10.125
# 495     Eugene    Male 1984-05-24 2018-03-10 10:54:00   81077    2.117
# 33        Jean  Female 1993-12-18 2018-03-10 09:07:00  119082   16.180
# 832      Keith    Male 2003-02-12 2018-03-10 15:02:00  120672   19.467
# 291      Tammy  Female 1984-11-11 2018-03-10 10:30:00  132839   17.463
#
#      Senior Management                  Team
# 8                 True           Engineering
# 688               True                 Legal
# 190              False               Finance
# 887              False                 Legal
# ...

# %%
# drop_duplicates() method 
# this method can be used on a data frame unlike the duplicates() method
# ... so can accomplish some of the above functions more easily

# %%
# reset 
df = pd.read_csv("data/employees.csv", parse_dates=["Start Date","Last Login Time"])
df["Senior Management"] = df["Senior Management"].astype(bool)
df["Gender"] = df["Gender"].astype("category")
df.sort_values("First Name", inplace=True)
df.head(10)
# Out:
#     First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 101      Aaron   Male 2012-02-17 2018-03-10 10:20:00   61602   11.849
# 327      Aaron   Male 1994-01-29 2018-03-10 18:48:00   58755    5.097
# 440      Aaron   Male 1990-07-22 2018-03-10 14:53:00   52119   11.343
# 937      Aaron    NaN 1986-01-22 2018-03-10 19:39:00   63126   18.424
# 137       Adam   Male 2011-05-21 2018-03-10 01:45:00   95327   15.120
# 141       Adam   Male 1990-12-24 2018-03-10 20:57:00  110194   14.727
# 302       Adam   Male 2007-07-05 2018-03-10 11:59:00   71276    5.027
# 538       Adam   Male 2010-10-08 2018-03-10 21:53:00   45181    3.491
# 300       Alan   Male 1988-06-26 2018-03-10 03:54:00  111786    3.592
# 53        Alan    NaN 2014-03-03 2018-03-10 13:28:00   40341   17.578
#
#      Senior Management             Team
# 101               True        Marketing
# 327               True        Marketing
# 440               True  Client Services
# ...

# %%
# how many rows ?
len(df)
# Out:
# 1000

# %%
len(df.drop_duplicates())
# Out:
# 1000

# %%
# why ?
# only works like this where rows are identical

# %%
# the subset parameter specifies a python list of which columns or column to consider - they are additive
df.drop_duplicates(subset=["First Name"], keep=False)  # displays just employees with unique firt names
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 8       Angela  Female 2005-11-22 2018-03-10 06:29:00   95570   18.523
# 688      Brian    Male 2007-04-07 2018-03-10 22:47:00   93901   17.821
# 190      Carol  Female 1996-03-19 2018-03-10 03:39:00   57783    9.129
# 887      David    Male 2009-12-05 2018-03-10 08:48:00   92242   15.407
# 5       Dennis    Male 1987-04-18 2018-03-10 01:35:00  115163   10.125
# 495     Eugene    Male 1984-05-24 2018-03-10 10:54:00   81077    2.117
# 33        Jean  Female 1993-12-18 2018-03-10 09:07:00  119082   16.180
# 832      Keith    Male 2003-02-12 2018-03-10 15:02:00  120672   19.467
# 291      Tammy  Female 1984-11-11 2018-03-10 10:30:00  132839   17.463
#
#      Senior Management                  Team
# 8                 True           Engineering
# 688               True                 Legal
# 190              False               Finance
# 887              False                 Legal
# ...

# %%
df.drop_duplicates(subset=["First Name","Start Date"],)
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 101      Aaron    Male 2012-02-17 2018-03-10 10:20:00   61602   11.849
# 327      Aaron    Male 1994-01-29 2018-03-10 18:48:00   58755    5.097
# 440      Aaron    Male 1990-07-22 2018-03-10 14:53:00   52119   11.343
# 937      Aaron     NaN 1986-01-22 2018-03-10 19:39:00   63126   18.424
# 137       Adam    Male 2011-05-21 2018-03-10 01:45:00   95327   15.120
# 141       Adam    Male 1990-12-24 2018-03-10 20:57:00  110194   14.727
# 302       Adam    Male 2007-07-05 2018-03-10 11:59:00   71276    5.027
# 538       Adam    Male 2010-10-08 2018-03-10 21:53:00   45181    3.491
# 300       Alan    Male 1988-06-26 2018-03-10 03:54:00  111786    3.592
# 53        Alan     NaN 2014-03-03 2018-03-10 13:28:00   40341   17.578
# 610       Alan    Male 2012-02-17 2018-03-10 00:26:00   41453   10.084
# 372     Albert    Male 1997-02-01 2018-03-10 16:20:00   67827   19.717
# ...

# %%
# using .loc[] .ilox[] ix[]

# %%
# first, .loc[]

# %%
# default import for this section 
bond = pd.read_csv('data/jamesbond.csv', index_col='Film')
bond.sort_index(inplace=True)
bond.head()
# Out:
#                       Year           Actor         Director  Box Office  \
# Film
# A View to a Kill      1985     Roger Moore        John Glen       275.2
# Casino Royale         2006    Daniel Craig  Martin Campbell       581.5
# Casino Royale         1967     David Niven       Ken Hughes       315.0
# Diamonds Are Forever  1971    Sean Connery     Guy Hamilton       442.5
# Die Another Day       2002  Pierce Brosnan     Lee Tamahori       465.4
#
#                       Budget  Bond Actor Salary
# Film
# A View to a Kill        54.5                9.1
# Casino Royale          145.3                3.3
# Casino Royale           85.0                NaN
# Diamonds Are Forever    34.7                5.8
# Die Another Day        154.2               17.9

# %% [markdown]
# ??
# is loc for string index and iloc for numbered index?

# %%
bond.loc['A View to a Kill']  # returns a series
# Out:
# Year                        1985
# Actor                Roger Moore
# Director               John Glen
# Box Office                 275.2
# Budget                      54.5
# Bond Actor Salary            9.1
# Name: A View to a Kill, dtype: object

# %%
bond.loc['Casino Royale' : 'Die Another Day']
# note this returns an inclusive result
# Out:
#                       Year           Actor         Director  Box Office  \
# Film
# Casino Royale         2006    Daniel Craig  Martin Campbell       581.5
# Casino Royale         1967     David Niven       Ken Hughes       315.0
# Diamonds Are Forever  1971    Sean Connery     Guy Hamilton       442.5
# Die Another Day       2002  Pierce Brosnan     Lee Tamahori       465.4
#
#                       Budget  Bond Actor Salary
# Film
# Casino Royale          145.3                3.3
# Casino Royale           85.0                NaN
# Diamonds Are Forever    34.7                5.8
# Die Another Day        154.2               17.9

# %%
# bracket notation works like this to pull everything from the beginning
bond.loc[: 'Diamonds Are Forever']
# Out:
#                       Year         Actor         Director  Box Office  Budget  \
# Film
# A View to a Kill      1985   Roger Moore        John Glen       275.2    54.5
# Casino Royale         2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale         1967   David Niven       Ken Hughes       315.0    85.0
# Diamonds Are Forever  1971  Sean Connery     Guy Hamilton       442.5    34.7
#
#                       Bond Actor Salary
# Film
# A View to a Kill                    9.1
# Casino Royale                       3.3
# Casino Royale                       NaN
# Diamonds Are Forever                5.8

# %%
# or to the end 
bond.loc['Quantum of Solace':]
# Out:
#                              Year           Actor            Director  \
# Film
# Quantum of Solace            2008    Daniel Craig        Marc Forster
# Skyfall                      2012    Daniel Craig          Sam Mendes
# Spectre                      2015    Daniel Craig          Sam Mendes
# The Living Daylights         1987  Timothy Dalton           John Glen
# The Man with the Golden Gun  1974     Roger Moore        Guy Hamilton
# The Spy Who Loved Me         1977     Roger Moore       Lewis Gilbert
# The World Is Not Enough      1999  Pierce Brosnan       Michael Apted
# Thunderball                  1965    Sean Connery       Terence Young
# Tomorrow Never Dies          1997  Pierce Brosnan  Roger Spottiswoode
# You Only Live Twice          1967    Sean Connery       Lewis Gilbert
#
#                              Box Office  Budget  Bond Actor Salary
# Film
# Quantum of Solace                 514.2   181.4                8.1
# ...

# %% [markdown]
# ## iloc[ ]
#
# extract by position using `.iloc[]`

# %%
bond = pd.read_csv('data/jamesbond.csv')
bond.sort_index(inplace=True)
bond.head()
# Out:
#                     Film  Year         Actor       Director  Box Office  \
# 0                 Dr. No  1962  Sean Connery  Terence Young       448.8
# 1  From Russia with Love  1963  Sean Connery  Terence Young       543.8
# 2             Goldfinger  1964  Sean Connery   Guy Hamilton       820.4
# 3            Thunderball  1965  Sean Connery  Terence Young       848.1
# 4          Casino Royale  1967   David Niven     Ken Hughes       315.0
#
#    Budget  Bond Actor Salary
# 0     7.0                0.6
# 1    12.6                1.6
# 2    18.6                3.2
# 3    41.9                4.7
# 4    85.0                NaN

# %%
bond.loc[15]
# Out:
# Film                 A View to a Kill
# Year                             1985
# Actor                     Roger Moore
# Director                    John Glen
# Box Office                      275.2
# Budget                           54.5
# Bond Actor Salary                 9.1
# Name: 15, dtype: object

# %%
bond.iloc[15]
# Out:
# Film                 A View to a Kill
# Year                             1985
# Actor                     Roger Moore
# Director                    John Glen
# Box Office                      275.2
# Budget                           54.5
# Bond Actor Salary                 9.1
# Name: 15, dtype: object

# %%
bond.iloc[[15,20]]
# Out:
#                        Film  Year           Actor       Director  Box Office  \
# 15         A View to a Kill  1985     Roger Moore      John Glen       275.2
# 20  The World Is Not Enough  1999  Pierce Brosnan  Michael Apted       439.5
#
#     Budget  Bond Actor Salary
# 15    54.5                9.1
# 20   158.3               13.5

# %%
bond.iloc[:4]
# Out:
#                     Film  Year         Actor       Director  Box Office  \
# 0                 Dr. No  1962  Sean Connery  Terence Young       448.8
# 1  From Russia with Love  1963  Sean Connery  Terence Young       543.8
# 2             Goldfinger  1964  Sean Connery   Guy Hamilton       820.4
# 3            Thunderball  1965  Sean Connery  Terence Young       848.1
#
#    Budget  Bond Actor Salary
# 0     7.0                0.6
# 1    12.6                1.6
# 2    18.6                3.2
# 3    41.9                4.7

# %%
bond.iloc[2:4]   # note last value not inclusive
# Out:
#           Film  Year         Actor       Director  Box Office  Budget  \
# 2   Goldfinger  1964  Sean Connery   Guy Hamilton       820.4    18.6
# 3  Thunderball  1965  Sean Connery  Terence Young       848.1    41.9
#
#    Bond Actor Salary
# 2                3.2
# 3                4.7

# %%
bond = pd.read_csv('data/jamesbond.csv', index_col='Film')
bond.sort_index(inplace=True)
bond.head(5)
# Out:
#                       Year           Actor         Director  Box Office  \
# Film
# A View to a Kill      1985     Roger Moore        John Glen       275.2
# Casino Royale         2006    Daniel Craig  Martin Campbell       581.5
# Casino Royale         1967     David Niven       Ken Hughes       315.0
# Diamonds Are Forever  1971    Sean Connery     Guy Hamilton       442.5
# Die Another Day       2002  Pierce Brosnan     Lee Tamahori       465.4
#
#                       Budget  Bond Actor Salary
# Film
# A View to a Kill        54.5                9.1
# Casino Royale          145.3                3.3
# Casino Royale           85.0                NaN
# Diamonds Are Forever    34.7                5.8
# Die Another Day        154.2               17.9

# %%
# note an index by label
# ... yet number index persists

# %%
bond.iloc[4] # returns the 5th record
# Out:
# Year                           2002
# Actor                Pierce Brosnan
# Director               Lee Tamahori
# Box Office                    465.4
# Budget                        154.2
# Bond Actor Salary              17.9
# Name: Die Another Day, dtype: object

# %% [markdown]
# ## `.ix[ ]` method
#
# the `.ix[ ]` method returns a deprecation warning to disregard `ix[ ]`

# %%
bond = pd.read_csv('data/jamesbond.csv', index_col='Film')
bond.sort_index(inplace=True)
bond.head()
# Out:
#                       Year           Actor         Director  Box Office  \
# Film
# A View to a Kill      1985     Roger Moore        John Glen       275.2
# Casino Royale         2006    Daniel Craig  Martin Campbell       581.5
# Casino Royale         1967     David Niven       Ken Hughes       315.0
# Diamonds Are Forever  1971    Sean Connery     Guy Hamilton       442.5
# Die Another Day       2002  Pierce Brosnan     Lee Tamahori       465.4
#
#                       Budget  Bond Actor Salary
# Film
# A View to a Kill        54.5                9.1
# Casino Royale          145.3                3.3
# Casino Royale           85.0                NaN
# Diamonds Are Forever    34.7                5.8
# Die Another Day        154.2               17.9

# %%
bond.ix['GoldenEye']
# Out:
# /Users/simonbaier/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# Year                            1995
# Actor                 Pierce Brosnan
# Director             Martin Campbell
# Box Office                     518.5
# Budget                          76.9
# Bond Actor Salary                5.1
# Name: GoldenEye, dtype: object

# %%
bond = pd.read_csv('data/jamesbond.csv', index_col='Film')
bond.sort_index(inplace=True)
bond.head()
# Out:
#                       Year           Actor         Director  Box Office  \
# Film
# A View to a Kill      1985     Roger Moore        John Glen       275.2
# Casino Royale         2006    Daniel Craig  Martin Campbell       581.5
# Casino Royale         1967     David Niven       Ken Hughes       315.0
# Diamonds Are Forever  1971    Sean Connery     Guy Hamilton       442.5
# Die Another Day       2002  Pierce Brosnan     Lee Tamahori       465.4
#
#                       Budget  Bond Actor Salary
# Film
# A View to a Kill        54.5                9.1
# Casino Royale          145.3                3.3
# Casino Royale           85.0                NaN
# Diamonds Are Forever    34.7                5.8
# Die Another Day        154.2               17.9

# %%
bond.loc["Moonraker", "Actor"]
# Out:
# 'Roger Moore'

# %%
bond.loc['Moonraker', ['Actor', 'Budget', 'Year']]
# Out:
# Actor     Roger Moore
# Budget           91.5
# Year             1979
# Name: Moonraker, dtype: object

# %%
bond.loc[['Moonraker','Spectre'], ['Actor', 'Budget', 'Year']]
# Out:
#                   Actor  Budget  Year
# Film
# Moonraker   Roger Moore    91.5  1979
# Spectre    Daniel Craig   206.3  2015

# %%
bond.iloc[[0,5,7,12],[0,2,3]]
# Out:
#                        Year       Director  Box Office
# Film
# A View to a Kill       1985      John Glen       275.2
# Dr. No                 1962  Terence Young       448.8
# From Russia with Love  1963  Terence Young       543.8
# Moonraker              1979  Lewis Gilbert       535.0

# %%
bond.iloc[4:16,[0,2,3,5]]
# Out:
#                                  Year         Director  Box Office  \
# Film
# Die Another Day                  2002     Lee Tamahori       465.4
# Dr. No                           1962    Terence Young       448.8
# For Your Eyes Only               1981        John Glen       449.4
# From Russia with Love            1963    Terence Young       543.8
# GoldenEye                        1995  Martin Campbell       518.5
# Goldfinger                       1964     Guy Hamilton       820.4
# Licence to Kill                  1989        John Glen       250.9
# Live and Let Die                 1973     Guy Hamilton       460.3
# Moonraker                        1979    Lewis Gilbert       535.0
# Never Say Never Again            1983   Irvin Kershner       380.0
# Octopussy                        1983        John Glen       373.8
# On Her Majesty's Secret Service  1969    Peter R. Hunt       291.5
#
#                                  Bond Actor Salary
# Film
# ...

# %%
bond.iloc[7:14,0:3]
# Out:
#                        Year           Actor         Director
# Film
# From Russia with Love  1963    Sean Connery    Terence Young
# GoldenEye              1995  Pierce Brosnan  Martin Campbell
# Goldfinger             1964    Sean Connery     Guy Hamilton
# Licence to Kill        1989  Timothy Dalton        John Glen
# Live and Let Die       1973     Roger Moore     Guy Hamilton
# Moonraker              1979     Roger Moore    Lewis Gilbert
# Never Say Never Again  1983    Sean Connery   Irvin Kershner

# %% [markdown]
# ## Set new cell value  - Update a value

# %%
bond.loc["Dr. No","Actor"]
# Out:
# 'Sean Connery'

# %%
bond.loc["Dr. No","Actor"] = "Simon Baier"
bond.loc["Dr. No","Actor"]
# Out:
# 'Simon Baier'

# %%
bond
# Out:
#                                  Year           Actor            Director  \
# Film
# A View to a Kill                 1985     Roger Moore           John Glen
# Casino Royale                    2006    Daniel Craig     Martin Campbell
# Casino Royale                    1967     David Niven          Ken Hughes
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Die Another Day                  2002  Pierce Brosnan        Lee Tamahori
# Dr. No                           1962     Simon Baier       Terence Young
# For Your Eyes Only               1981     Roger Moore           John Glen
# From Russia with Love            1963    Sean Connery       Terence Young
# GoldenEye                        1995  Pierce Brosnan     Martin Campbell
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# Licence to Kill                  1989  Timothy Dalton           John Glen
# Live and Let Die                 1973     Roger Moore        Guy Hamilton
# ...

# %% [markdown]
# ## Set multiple values in `dataframe`

# %%
bond = pd.read_csv('data/jamesbond.csv', index_col='Film')
bond.sort_index(inplace=True)
bond.head()
# Out:
#                       Year           Actor         Director  Box Office  \
# Film
# A View to a Kill      1985     Roger Moore        John Glen       275.2
# Casino Royale         2006    Daniel Craig  Martin Campbell       581.5
# Casino Royale         1967     David Niven       Ken Hughes       315.0
# Diamonds Are Forever  1971    Sean Connery     Guy Hamilton       442.5
# Die Another Day       2002  Pierce Brosnan     Lee Tamahori       465.4
#
#                       Budget  Bond Actor Salary
# Film
# A View to a Kill        54.5                9.1
# Casino Royale          145.3                3.3
# Casino Royale           85.0                NaN
# Diamonds Are Forever    34.7                5.8
# Die Another Day        154.2               17.9

# %%
# change all Sean Connery's with "Sir Sean Connery"

# %%
mask = bond['Actor'] == "Sean Connery"
bond[mask]
# Out:
#                        Year         Actor        Director  Box Office  Budget  \
# Film
# Diamonds Are Forever   1971  Sean Connery    Guy Hamilton       442.5    34.7
# Dr. No                 1962  Sean Connery   Terence Young       448.8     7.0
# From Russia with Love  1963  Sean Connery   Terence Young       543.8    12.6
# Goldfinger             1964  Sean Connery    Guy Hamilton       820.4    18.6
# Never Say Never Again  1983  Sean Connery  Irvin Kershner       380.0    86.0
# Thunderball            1965  Sean Connery   Terence Young       848.1    41.9
# You Only Live Twice    1967  Sean Connery   Lewis Gilbert       514.2    59.9
#
#                        Bond Actor Salary
# Film
# Diamonds Are Forever                 5.8
# Dr. No                               0.6
# From Russia with Love                1.6
# Goldfinger                           3.2
# Never Say Never Again                NaN
# Thunderball                          4.7
# ...

# %%
bond.loc[mask]  # this is not a copy, it is a view of original
# Out:
#                        Year         Actor        Director  Box Office  Budget  \
# Film
# Diamonds Are Forever   1971  Sean Connery    Guy Hamilton       442.5    34.7
# Dr. No                 1962  Sean Connery   Terence Young       448.8     7.0
# From Russia with Love  1963  Sean Connery   Terence Young       543.8    12.6
# Goldfinger             1964  Sean Connery    Guy Hamilton       820.4    18.6
# Never Say Never Again  1983  Sean Connery  Irvin Kershner       380.0    86.0
# Thunderball            1965  Sean Connery   Terence Young       848.1    41.9
# You Only Live Twice    1967  Sean Connery   Lewis Gilbert       514.2    59.9
#
#                        Bond Actor Salary
# Film
# Diamonds Are Forever                 5.8
# Dr. No                               0.6
# From Russia with Love                1.6
# Goldfinger                           3.2
# Never Say Never Again                NaN
# Thunderball                          4.7
# ...

# %%
bond.loc[mask, 'Actor'] = 'Sir Sean Connery'
bond.head(10)
# Out:
#                        Year             Actor         Director  Box Office  \
# Film
# A View to a Kill       1985       Roger Moore        John Glen       275.2
# Casino Royale          2006      Daniel Craig  Martin Campbell       581.5
# Casino Royale          1967       David Niven       Ken Hughes       315.0
# Diamonds Are Forever   1971  Sir Sean Connery     Guy Hamilton       442.5
# Die Another Day        2002    Pierce Brosnan     Lee Tamahori       465.4
# Dr. No                 1962  Sir Sean Connery    Terence Young       448.8
# For Your Eyes Only     1981       Roger Moore        John Glen       449.4
# From Russia with Love  1963  Sir Sean Connery    Terence Young       543.8
# GoldenEye              1995    Pierce Brosnan  Martin Campbell       518.5
# Goldfinger             1964  Sir Sean Connery     Guy Hamilton       820.4
#
#                        Budget  Bond Actor Salary
# Film
# A View to a Kill         54.5                9.1
# ...

# %%
# long form looks like this 
bond.loc[bond['Actor'] == "Sir Sean Connery", 'Actor'] = 'Sir Poop Connery'
bond
# this is very confusing
# Out:
#                                  Year             Actor            Director  \
# Film
# A View to a Kill                 1985       Roger Moore           John Glen
# Casino Royale                    2006      Daniel Craig     Martin Campbell
# Casino Royale                    1967       David Niven          Ken Hughes
# Diamonds Are Forever             1971  Sir Poop Connery        Guy Hamilton
# Die Another Day                  2002    Pierce Brosnan        Lee Tamahori
# Dr. No                           1962  Sir Poop Connery       Terence Young
# For Your Eyes Only               1981       Roger Moore           John Glen
# From Russia with Love            1963  Sir Poop Connery       Terence Young
# GoldenEye                        1995    Pierce Brosnan     Martin Campbell
# Goldfinger                       1964  Sir Poop Connery        Guy Hamilton
# Licence to Kill                  1989    Timothy Dalton           John Glen
# ...

# %%
bond = pd.read_csv('data/jamesbond.csv', index_col='Film')
bond.sort_index(inplace=True)
bond.head()
# Out:
#                       Year           Actor         Director  Box Office  \
# Film
# A View to a Kill      1985     Roger Moore        John Glen       275.2
# Casino Royale         2006    Daniel Craig  Martin Campbell       581.5
# Casino Royale         1967     David Niven       Ken Hughes       315.0
# Diamonds Are Forever  1971    Sean Connery     Guy Hamilton       442.5
# Die Another Day       2002  Pierce Brosnan     Lee Tamahori       465.4
#
#                       Budget  Bond Actor Salary
# Film
# A View to a Kill        54.5                9.1
# Casino Royale          145.3                3.3
# Casino Royale           85.0                NaN
# Diamonds Are Forever    34.7                5.8
# Die Another Day        154.2               17.9

# %% [markdown]
# ## rename columns

# %%
bond.rename(columns = {'Year':'Release Date', 'Box Office' : 'Revenue'}, inplace = True)
bond.head()
# Out:
#                       Release Date           Actor         Director  Revenue  \
# Film
# A View to a Kill              1985     Roger Moore        John Glen    275.2
# Casino Royale                 2006    Daniel Craig  Martin Campbell    581.5
# Casino Royale                 1967     David Niven       Ken Hughes    315.0
# Diamonds Are Forever          1971    Sean Connery     Guy Hamilton    442.5
# Die Another Day               2002  Pierce Brosnan     Lee Tamahori    465.4
#
#                       Budget  Bond Actor Salary
# Film
# A View to a Kill        54.5                9.1
# Casino Royale          145.3                3.3
# Casino Royale           85.0                NaN
# Diamonds Are Forever    34.7                5.8
# Die Another Day        154.2               17.9

# %% [markdown]
# ## rename index values

# %%
bond.rename(index = 
            {
                'Dr. No' : 'Doctor No',
                'GoldenEye' : 'Golden Eye'
            }, inplace = True
           )

# %%
bond
# Out:
#                                  Release Date           Actor  \
# Film
# A View to a Kill                         1985     Roger Moore
# Casino Royale                            2006    Daniel Craig
# Casino Royale                            1967     David Niven
# Diamonds Are Forever                     1971    Sean Connery
# Die Another Day                          2002  Pierce Brosnan
# Doctor No                                1962    Sean Connery
# For Your Eyes Only                       1981     Roger Moore
# From Russia with Love                    1963    Sean Connery
# Golden Eye                               1995  Pierce Brosnan
# Goldfinger                               1964    Sean Connery
# Licence to Kill                          1989  Timothy Dalton
# Live and Let Die                         1973     Roger Moore
# Moonraker                                1979     Roger Moore
# Never Say Never Again                    1983    Sean Connery
# ...

# %%
bond.columns
# Out:
# Index(['Release Date', 'Actor', 'Director', 'Revenue', 'Budget',
#        'Bond Actor Salary'],
#       dtype='object')

# %%
bond.columns = ['Release Date', 'Actor', 'Director', 'Gross', 'Cost',
       'Salary']
bond.head()
# Out:
#                       Release Date           Actor         Director  Gross  \
# Film
# A View to a Kill              1985     Roger Moore        John Glen  275.2
# Casino Royale                 2006    Daniel Craig  Martin Campbell  581.5
# Casino Royale                 1967     David Niven       Ken Hughes  315.0
# Diamonds Are Forever          1971    Sean Connery     Guy Hamilton  442.5
# Die Another Day               2002  Pierce Brosnan     Lee Tamahori  465.4
#
#                        Cost  Salary
# Film
# A View to a Kill       54.5     9.1
# Casino Royale         145.3     3.3
# Casino Royale          85.0     NaN
# Diamonds Are Forever   34.7     5.8
# Die Another Day       154.2    17.9

# %%
# reimport

# %%
bond = pd.read_csv('data/jamesbond.csv', index_col='Film')
bond.sort_index(inplace=True)
bond.head()
# Out:
#                       Year           Actor         Director  Box Office  \
# Film
# A View to a Kill      1985     Roger Moore        John Glen       275.2
# Casino Royale         2006    Daniel Craig  Martin Campbell       581.5
# Casino Royale         1967     David Niven       Ken Hughes       315.0
# Diamonds Are Forever  1971    Sean Connery     Guy Hamilton       442.5
# Die Another Day       2002  Pierce Brosnan     Lee Tamahori       465.4
#
#                       Budget  Bond Actor Salary
# Film
# A View to a Kill        54.5                9.1
# Casino Royale          145.3                3.3
# Casino Royale           85.0                NaN
# Diamonds Are Forever    34.7                5.8
# Die Another Day        154.2               17.9

# %%
# remove a row or record

# %%
bond.drop(['A View to a Kill', 'Die Another Day']).head()
# Out:
#                       Year         Actor         Director  Box Office  Budget  \
# Film
# Casino Royale         2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale         1967   David Niven       Ken Hughes       315.0    85.0
# Diamonds Are Forever  1971  Sean Connery     Guy Hamilton       442.5    34.7
# Dr. No                1962  Sean Connery    Terence Young       448.8     7.0
# For Your Eyes Only    1981   Roger Moore        John Glen       449.4    60.2
#
#                       Bond Actor Salary
# Film
# Casino Royale                       3.3
# Casino Royale                       NaN
# Diamonds Are Forever                5.8
# Dr. No                              0.6
# For Your Eyes Only                  NaN

# %%
# remove a column

# %%
bond.drop('Box Office', axis = 1).head()
# Out:
#                       Year           Actor         Director  Budget  \
# Film
# A View to a Kill      1985     Roger Moore        John Glen    54.5
# Casino Royale         2006    Daniel Craig  Martin Campbell   145.3
# Casino Royale         1967     David Niven       Ken Hughes    85.0
# Diamonds Are Forever  1971    Sean Connery     Guy Hamilton    34.7
# Die Another Day       2002  Pierce Brosnan     Lee Tamahori   154.2
#
#                       Bond Actor Salary
# Film
# A View to a Kill                    9.1
# Casino Royale                       3.3
# Casino Royale                       NaN
# Diamonds Are Forever                5.8
# Die Another Day                    17.9

# %% [markdown]
# ## pop() method
# re execute

# %%
bond = pd.read_csv('data/jamesbond.csv', index_col='Film')
bond.sort_index(inplace=True)
bond.head()
# Out:
#                       Year           Actor         Director  Box Office  \
# Film
# A View to a Kill      1985     Roger Moore        John Glen       275.2
# Casino Royale         2006    Daniel Craig  Martin Campbell       581.5
# Casino Royale         1967     David Niven       Ken Hughes       315.0
# Diamonds Are Forever  1971    Sean Connery     Guy Hamilton       442.5
# Die Another Day       2002  Pierce Brosnan     Lee Tamahori       465.4
#
#                       Budget  Bond Actor Salary
# Film
# A View to a Kill        54.5                9.1
# Casino Royale          145.3                3.3
# Casino Royale           85.0                NaN
# Diamonds Are Forever    34.7                5.8
# Die Another Day        154.2               17.9

# %%
actor = bond.pop("Actor")

# %%
actor
# Out:
# Film
# A View to a Kill                      Roger Moore
# Casino Royale                        Daniel Craig
# Casino Royale                         David Niven
# Diamonds Are Forever                 Sean Connery
# Die Another Day                    Pierce Brosnan
# Dr. No                               Sean Connery
# For Your Eyes Only                    Roger Moore
# From Russia with Love                Sean Connery
# GoldenEye                          Pierce Brosnan
# Goldfinger                           Sean Connery
# Licence to Kill                    Timothy Dalton
# Live and Let Die                      Roger Moore
# Moonraker                             Roger Moore
# Never Say Never Again                Sean Connery
# Octopussy                             Roger Moore
# On Her Majesty's Secret Service    George Lazenby
# Quantum of Solace                    Daniel Craig
# Skyfall                              Daniel Craig
# Spectre                              Daniel Craig
# ...

# %% [markdown]
# ## del()

# %%
bond = pd.read_csv('data/jamesbond.csv', index_col='Film')
bond.sort_index(inplace=True)
bond.head()
# Out:
#                       Year           Actor         Director  Box Office  \
# Film
# A View to a Kill      1985     Roger Moore        John Glen       275.2
# Casino Royale         2006    Daniel Craig  Martin Campbell       581.5
# Casino Royale         1967     David Niven       Ken Hughes       315.0
# Diamonds Are Forever  1971    Sean Connery     Guy Hamilton       442.5
# Die Another Day       2002  Pierce Brosnan     Lee Tamahori       465.4
#
#                       Budget  Bond Actor Salary
# Film
# A View to a Kill        54.5                9.1
# Casino Royale          145.3                3.3
# Casino Royale           85.0                NaN
# Diamonds Are Forever    34.7                5.8
# Die Another Day        154.2               17.9

# %%
del bond['Director']  # alt method to delete a column - no implace necessary

# %%
bond.head()
# Out:
#                       Year           Actor  Box Office  Budget  \
# Film
# A View to a Kill      1985     Roger Moore       275.2    54.5
# Casino Royale         2006    Daniel Craig       581.5   145.3
# Casino Royale         1967     David Niven       315.0    85.0
# Diamonds Are Forever  1971    Sean Connery       442.5    34.7
# Die Another Day       2002  Pierce Brosnan       465.4   154.2
#
#                       Bond Actor Salary
# Film
# A View to a Kill                    9.1
# Casino Royale                       3.3
# Casino Royale                       NaN
# Diamonds Are Forever                5.8
# Die Another Day                    17.9

# %% [markdown]
# ## select random rows from dataframe

# %%
bond = pd.read_csv('data/jamesbond.csv', index_col='Film')
bond.sort_index(inplace=True)
bond.head()
# Out:
#                       Year           Actor         Director  Box Office  \
# Film
# A View to a Kill      1985     Roger Moore        John Glen       275.2
# Casino Royale         2006    Daniel Craig  Martin Campbell       581.5
# Casino Royale         1967     David Niven       Ken Hughes       315.0
# Diamonds Are Forever  1971    Sean Connery     Guy Hamilton       442.5
# Die Another Day       2002  Pierce Brosnan     Lee Tamahori       465.4
#
#                       Budget  Bond Actor Salary
# Film
# A View to a Kill        54.5                9.1
# Casino Royale          145.3                3.3
# Casino Royale           85.0                NaN
# Diamonds Are Forever    34.7                5.8
# Die Another Day        154.2               17.9

# %%
bond.sample()  # returns one random row
# Out:
#                Year         Actor         Director  Box Office  Budget  \
# Film
# Casino Royale  2006  Daniel Craig  Martin Campbell       581.5   145.3
#
#                Bond Actor Salary
# Film
# Casino Royale                3.3

# %%
bond.sample()
# Out:
#                       Year         Actor      Director  Box Office  Budget  \
# Film
# Diamonds Are Forever  1971  Sean Connery  Guy Hamilton       442.5    34.7
#
#                       Bond Actor Salary
# Film
# Diamonds Are Forever                5.8

# %%
bond.sample(5)  # not necessarily in order
# Out:
#                        Year           Actor         Director  Box Office  \
# Film
# Moonraker              1979     Roger Moore    Lewis Gilbert       535.0
# From Russia with Love  1963    Sean Connery    Terence Young       543.8
# GoldenEye              1995  Pierce Brosnan  Martin Campbell       518.5
# Never Say Never Again  1983    Sean Connery   Irvin Kershner       380.0
# Spectre                2015    Daniel Craig       Sam Mendes       726.7
#
#                        Budget  Bond Actor Salary
# Film
# Moonraker                91.5                NaN
# From Russia with Love    12.6                1.6
# GoldenEye                76.9                5.1
# Never Say Never Again    86.0                NaN
# Spectre                 206.3                NaN

# %%
bond.sample(n=5)  # same as above
# Out:
#                              Year         Actor      Director  Box Office  \
# Film
# A View to a Kill             1985   Roger Moore     John Glen       275.2
# Spectre                      2015  Daniel Craig    Sam Mendes       726.7
# Skyfall                      2012  Daniel Craig    Sam Mendes       943.5
# Diamonds Are Forever         1971  Sean Connery  Guy Hamilton       442.5
# The Man with the Golden Gun  1974   Roger Moore  Guy Hamilton       334.0
#
#                              Budget  Bond Actor Salary
# Film
# A View to a Kill               54.5                9.1
# Spectre                       206.3                NaN
# Skyfall                       170.2               14.5
# Diamonds Are Forever           34.7                5.8
# The Man with the Golden Gun    27.7                NaN

# %%
bond.sample(frac=.2)  # returns a randome fraction
# Out:
#                                  Year           Actor       Director  \
# Film
# Moonraker                        1979     Roger Moore  Lewis Gilbert
# Casino Royale                    1967     David Niven     Ken Hughes
# Octopussy                        1983     Roger Moore      John Glen
# Dr. No                           1962    Sean Connery  Terence Young
# On Her Majesty's Secret Service  1969  George Lazenby  Peter R. Hunt
#
#                                  Box Office  Budget  Bond Actor Salary
# Film
# Moonraker                             535.0    91.5                NaN
# Casino Royale                         315.0    85.0                NaN
# Octopussy                             373.8    53.9                7.8
# Dr. No                                448.8     7.0                0.6
# On Her Majesty's Secret Service       291.5    37.3                0.6

# %%
bond.sample(frac = .2, axis = 0) # same as above .. can use axis to select random cols
# Out:
#                       Year           Actor            Director  Box Office  \
# Film
# Tomorrow Never Dies   1997  Pierce Brosnan  Roger Spottiswoode       463.2
# Casino Royale         1967     David Niven          Ken Hughes       315.0
# Diamonds Are Forever  1971    Sean Connery        Guy Hamilton       442.5
# Spectre               2015    Daniel Craig          Sam Mendes       726.7
# GoldenEye             1995  Pierce Brosnan     Martin Campbell       518.5
#
#                       Budget  Bond Actor Salary
# Film
# Tomorrow Never Dies    133.9               10.0
# Casino Royale           85.0                NaN
# Diamonds Are Forever    34.7                5.8
# Spectre                206.3                NaN
# GoldenEye               76.9                5.1

# %% [markdown]
# ## largest and smallest values in a column

# %%
# select ten largest box office results
bond = pd.read_csv('data/jamesbond.csv', index_col='Film')
bond.sort_index(inplace=True)
bond.head()

bond.sort_values('Box Office',ascending=False).head(10)
# Out:
#                        Year           Actor         Director  Box Office  \
# Film
# Skyfall                2012    Daniel Craig       Sam Mendes       943.5
# Thunderball            1965    Sean Connery    Terence Young       848.1
# Goldfinger             1964    Sean Connery     Guy Hamilton       820.4
# Spectre                2015    Daniel Craig       Sam Mendes       726.7
# Casino Royale          2006    Daniel Craig  Martin Campbell       581.5
# From Russia with Love  1963    Sean Connery    Terence Young       543.8
# Moonraker              1979     Roger Moore    Lewis Gilbert       535.0
# The Spy Who Loved Me   1977     Roger Moore    Lewis Gilbert       533.0
# GoldenEye              1995  Pierce Brosnan  Martin Campbell       518.5
# Quantum of Solace      2008    Daniel Craig     Marc Forster       514.2
#
#                        Budget  Bond Actor Salary
# Film
# Skyfall                 170.2               14.5
# Thunderball              41.9                4.7
# ...

# %%
# or alternately use 
bond.nlargest(10,columns = "Box Office")  # more efficient than above method
# Out:
#                        Year           Actor         Director  Box Office  \
# Film
# Skyfall                2012    Daniel Craig       Sam Mendes       943.5
# Thunderball            1965    Sean Connery    Terence Young       848.1
# Goldfinger             1964    Sean Connery     Guy Hamilton       820.4
# Spectre                2015    Daniel Craig       Sam Mendes       726.7
# Casino Royale          2006    Daniel Craig  Martin Campbell       581.5
# From Russia with Love  1963    Sean Connery    Terence Young       543.8
# Moonraker              1979     Roger Moore    Lewis Gilbert       535.0
# The Spy Who Loved Me   1977     Roger Moore    Lewis Gilbert       533.0
# GoldenEye              1995  Pierce Brosnan  Martin Campbell       518.5
# Quantum of Solace      2008    Daniel Craig     Marc Forster       514.2
#
#                        Budget  Bond Actor Salary
# Film
# Skyfall                 170.2               14.5
# Thunderball              41.9                4.7
# ...

# %%
# three smallest salarys 
bond.nsmallest(3,"Bond Actor Salary")
# Out:
#                                  Year           Actor       Director  \
# Film
# Dr. No                           1962    Sean Connery  Terence Young
# On Her Majesty's Secret Service  1969  George Lazenby  Peter R. Hunt
# From Russia with Love            1963    Sean Connery  Terence Young
#
#                                  Box Office  Budget  Bond Actor Salary
# Film
# Dr. No                                448.8     7.0                0.6
# On Her Majesty's Secret Service       291.5    37.3                0.6
# From Russia with Love                 543.8    12.6                1.6

# %%
# also works on series
bond["Budget"].nsmallest(3)
# Out:
# Film
# Dr. No                    7.0
# From Russia with Love    12.6
# Goldfinger               18.6
# Name: Budget, dtype: float64

# %% [markdown]
# ## filtering with `where()` method

# %%
bond = pd.read_csv('data/jamesbond.csv', index_col='Film')
bond.sort_index(inplace=True)
bond.head()
# Out:
#                       Year           Actor         Director  Box Office  \
# Film
# A View to a Kill      1985     Roger Moore        John Glen       275.2
# Casino Royale         2006    Daniel Craig  Martin Campbell       581.5
# Casino Royale         1967     David Niven       Ken Hughes       315.0
# Diamonds Are Forever  1971    Sean Connery     Guy Hamilton       442.5
# Die Another Day       2002  Pierce Brosnan     Lee Tamahori       465.4
#
#                       Budget  Bond Actor Salary
# Film
# A View to a Kill        54.5                9.1
# Casino Royale          145.3                3.3
# Casino Royale           85.0                NaN
# Diamonds Are Forever    34.7                5.8
# Die Another Day        154.2               17.9

# %%
mask = bond["Actor"] == "Sean Connery"
bond[mask]
# Out:
#                        Year         Actor        Director  Box Office  Budget  \
# Film
# Diamonds Are Forever   1971  Sean Connery    Guy Hamilton       442.5    34.7
# Dr. No                 1962  Sean Connery   Terence Young       448.8     7.0
# From Russia with Love  1963  Sean Connery   Terence Young       543.8    12.6
# Goldfinger             1964  Sean Connery    Guy Hamilton       820.4    18.6
# Never Say Never Again  1983  Sean Connery  Irvin Kershner       380.0    86.0
# Thunderball            1965  Sean Connery   Terence Young       848.1    41.9
# You Only Live Twice    1967  Sean Connery   Lewis Gilbert       514.2    59.9
#
#                        Bond Actor Salary
# Film
# Diamonds Are Forever                 5.8
# Dr. No                               0.6
# From Russia with Love                1.6
# Goldfinger                           3.2
# Never Say Never Again                NaN
# Thunderball                          4.7
# ...

# %%
# alternately use where() method
bond.where(mask)
# Out:
#                                    Year         Actor        Director  \
# Film
# A View to a Kill                    NaN           NaN             NaN
# Casino Royale                       NaN           NaN             NaN
# Casino Royale                       NaN           NaN             NaN
# Diamonds Are Forever             1971.0  Sean Connery    Guy Hamilton
# Die Another Day                     NaN           NaN             NaN
# Dr. No                           1962.0  Sean Connery   Terence Young
# For Your Eyes Only                  NaN           NaN             NaN
# From Russia with Love            1963.0  Sean Connery   Terence Young
# GoldenEye                           NaN           NaN             NaN
# Goldfinger                       1964.0  Sean Connery    Guy Hamilton
# Licence to Kill                     NaN           NaN             NaN
# Live and Let Die                    NaN           NaN             NaN
# ...

# %%
# long form
bond.where(bond['Box Office'] > 800)
# Out:
#                                    Year         Actor       Director  \
# Film
# A View to a Kill                    NaN           NaN            NaN
# Casino Royale                       NaN           NaN            NaN
# Casino Royale                       NaN           NaN            NaN
# Diamonds Are Forever                NaN           NaN            NaN
# Die Another Day                     NaN           NaN            NaN
# Dr. No                              NaN           NaN            NaN
# For Your Eyes Only                  NaN           NaN            NaN
# From Russia with Love               NaN           NaN            NaN
# GoldenEye                           NaN           NaN            NaN
# Goldfinger                       1964.0  Sean Connery   Guy Hamilton
# Licence to Kill                     NaN           NaN            NaN
# Live and Let Die                    NaN           NaN            NaN
# ...

# %%
mask2 = bond['Box Office'] > 800

# %%
bond.where(mask & mask2)  # where both conditions are true
# Out:
#                                    Year         Actor       Director  \
# Film
# A View to a Kill                    NaN           NaN            NaN
# Casino Royale                       NaN           NaN            NaN
# Casino Royale                       NaN           NaN            NaN
# Diamonds Are Forever                NaN           NaN            NaN
# Die Another Day                     NaN           NaN            NaN
# Dr. No                              NaN           NaN            NaN
# For Your Eyes Only                  NaN           NaN            NaN
# From Russia with Love               NaN           NaN            NaN
# GoldenEye                           NaN           NaN            NaN
# Goldfinger                       1964.0  Sean Connery   Guy Hamilton
# Licence to Kill                     NaN           NaN            NaN
# Live and Let Die                    NaN           NaN            NaN
# ...

# %% [markdown]
# ## filtering with query() method

# %%
import pandas as pd 
bond = pd.read_csv('data/jamesbond.csv', index_col='Film')
bond.sort_index(inplace=True)
bond.head()
# requires underscores in column names
# Out:
#                       Year           Actor         Director  Box Office  \
# Film
# A View to a Kill      1985     Roger Moore        John Glen       275.2
# Casino Royale         2006    Daniel Craig  Martin Campbell       581.5
# Casino Royale         1967     David Niven       Ken Hughes       315.0
# Diamonds Are Forever  1971    Sean Connery     Guy Hamilton       442.5
# Die Another Day       2002  Pierce Brosnan     Lee Tamahori       465.4
#
#                       Budget  Bond Actor Salary
# Film
# A View to a Kill        54.5                9.1
# Casino Royale          145.3                3.3
# Casino Royale           85.0                NaN
# Diamonds Are Forever    34.7                5.8
# Die Another Day        154.2               17.9

# %%
bond.columns
# Out:
# Index(['Year', 'Actor', 'Director', 'Box Office', 'Budget',
#        'Bond Actor Salary'],
#       dtype='object')

# %%
# the following line creates a python list using a bracketed for loop 
# ... using python list comprehension technique 

[column_name.replace(" ", "_") for column_name in bond.columns]
bond.head(1)
# Out:
#                   Year        Actor   Director  Box Office  Budget  \
# Film
# A View to a Kill  1985  Roger Moore  John Glen       275.2    54.5
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1

# %%
bond.columns = [column_name.replace(" ", "_") for column_name in bond.columns]
bond.columns
# Out:
# Index(['Year', 'Actor', 'Director', 'Box_Office', 'Budget',
#        'Bond_Actor_Salary'],
#       dtype='object')

# %%
bond.query('Actor == "Sean Connery"')
# Out:
#                        Year         Actor        Director  Box_Office  Budget  \
# Film
# Diamonds Are Forever   1971  Sean Connery    Guy Hamilton       442.5    34.7
# Dr. No                 1962  Sean Connery   Terence Young       448.8     7.0
# From Russia with Love  1963  Sean Connery   Terence Young       543.8    12.6
# Goldfinger             1964  Sean Connery    Guy Hamilton       820.4    18.6
# Never Say Never Again  1983  Sean Connery  Irvin Kershner       380.0    86.0
# Thunderball            1965  Sean Connery   Terence Young       848.1    41.9
# You Only Live Twice    1967  Sean Connery   Lewis Gilbert       514.2    59.9
#
#                        Bond_Actor_Salary
# Film
# Diamonds Are Forever                 5.8
# Dr. No                               0.6
# From Russia with Love                1.6
# Goldfinger                           3.2
# Never Say Never Again                NaN
# Thunderball                          4.7
# ...

# %%
bond.query("Director == 'Terence Young'")
# Out:
#                        Year         Actor       Director  Box_Office  Budget  \
# Film
# Dr. No                 1962  Sean Connery  Terence Young       448.8     7.0
# From Russia with Love  1963  Sean Connery  Terence Young       543.8    12.6
# Thunderball            1965  Sean Connery  Terence Young       848.1    41.9
#
#                        Bond_Actor_Salary
# Film
# Dr. No                               0.6
# From Russia with Love                1.6
# Thunderball                          4.7

# %%
bond.query("Actor !='Roger Moore'").head()
# Out:
#                                  Year           Actor            Director  \
# Film
# Casino Royale                    2006    Daniel Craig     Martin Campbell
# Casino Royale                    1967     David Niven          Ken Hughes
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Die Another Day                  2002  Pierce Brosnan        Lee Tamahori
# Dr. No                           1962    Sean Connery       Terence Young
# From Russia with Love            1963    Sean Connery       Terence Young
# GoldenEye                        1995  Pierce Brosnan     Martin Campbell
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# Licence to Kill                  1989  Timothy Dalton           John Glen
# Never Say Never Again            1983    Sean Connery      Irvin Kershner
# On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# Quantum of Solace                2008    Daniel Craig        Marc Forster
# ...

# %%
bond.query("Box_Office > 600")
# Out:
#              Year         Actor       Director  Box_Office  Budget  \
# Film
# Goldfinger   1964  Sean Connery   Guy Hamilton       820.4    18.6
# Skyfall      2012  Daniel Craig     Sam Mendes       943.5   170.2
# Spectre      2015  Daniel Craig     Sam Mendes       726.7   206.3
# Thunderball  1965  Sean Connery  Terence Young       848.1    41.9
#
#              Bond_Actor_Salary
# Film
# Goldfinger                 3.2
# Skyfall                   14.5
# Spectre                    NaN
# Thunderball                4.7

# %%
bond.query("Actor == 'Roger Moore' or Director == 'John Glen'")
# Out:
#                              Year           Actor       Director  Box_Office  \
# Film
# A View to a Kill             1985     Roger Moore      John Glen       275.2
# For Your Eyes Only           1981     Roger Moore      John Glen       449.4
# Licence to Kill              1989  Timothy Dalton      John Glen       250.9
# Live and Let Die             1973     Roger Moore   Guy Hamilton       460.3
# Moonraker                    1979     Roger Moore  Lewis Gilbert       535.0
# Octopussy                    1983     Roger Moore      John Glen       373.8
# The Living Daylights         1987  Timothy Dalton      John Glen       313.5
# The Man with the Golden Gun  1974     Roger Moore   Guy Hamilton       334.0
# The Spy Who Loved Me         1977     Roger Moore  Lewis Gilbert       533.0
#
#                              Budget  Bond_Actor_Salary
# Film
# A View to a Kill               54.5                9.1
# For Your Eyes Only             60.2                NaN
# ...

# %%
bond.query("Actor in ['Timothy Dalton', 'Roger Moore']")
# Out:
#                              Year           Actor       Director  Box_Office  \
# Film
# A View to a Kill             1985     Roger Moore      John Glen       275.2
# For Your Eyes Only           1981     Roger Moore      John Glen       449.4
# Licence to Kill              1989  Timothy Dalton      John Glen       250.9
# Live and Let Die             1973     Roger Moore   Guy Hamilton       460.3
# Moonraker                    1979     Roger Moore  Lewis Gilbert       535.0
# Octopussy                    1983     Roger Moore      John Glen       373.8
# The Living Daylights         1987  Timothy Dalton      John Glen       313.5
# The Man with the Golden Gun  1974     Roger Moore   Guy Hamilton       334.0
# The Spy Who Loved Me         1977     Roger Moore  Lewis Gilbert       533.0
#
#                              Budget  Bond_Actor_Salary
# Film
# A View to a Kill               54.5                9.1
# For Your Eyes Only             60.2                NaN
# ...

# %% [markdown]
# # review .apply() method
#
# the apply() method applys a function (either python or custom) to a series

# %%
bond = pd.read_csv('data/jamesbond.csv', index_col='Film')
bond.sort_index(inplace=True)
bond.head()
# Out:
#                       Year           Actor         Director  Box Office  \
# Film
# A View to a Kill      1985     Roger Moore        John Glen       275.2
# Casino Royale         2006    Daniel Craig  Martin Campbell       581.5
# Casino Royale         1967     David Niven       Ken Hughes       315.0
# Diamonds Are Forever  1971    Sean Connery     Guy Hamilton       442.5
# Die Another Day       2002  Pierce Brosnan     Lee Tamahori       465.4
#
#                       Budget  Bond Actor Salary
# Film
# A View to a Kill        54.5                9.1
# Casino Royale          145.3                3.3
# Casino Royale           85.0                NaN
# Diamonds Are Forever    34.7                5.8
# Die Another Day        154.2               17.9

# %%
def convert_to_strings_and_add_to_millions(n):
    return str(n) + " million"

# %%
type(bond['Box Office'])  # a pandas Series
# Out:
# pandas.core.series.Series

# %%
bond['Box Office'].apply(convert_to_strings_and_add_to_millions) # applies function to a Series
# Out:
# Film
# A View to a Kill                   275.2 million
# Casino Royale                      581.5 million
# Casino Royale                      315.0 million
# Diamonds Are Forever               442.5 million
# Die Another Day                    465.4 million
# Dr. No                             448.8 million
# For Your Eyes Only                 449.4 million
# From Russia with Love              543.8 million
# GoldenEye                          518.5 million
# Goldfinger                         820.4 million
# Licence to Kill                    250.9 million
# Live and Let Die                   460.3 million
# Moonraker                          535.0 million
# Never Say Never Again              380.0 million
# Octopussy                          373.8 million
# On Her Majesty's Secret Service    291.5 million
# Quantum of Solace                  514.2 million
# Skyfall                            943.5 million
# Spectre                            726.7 million
# ...

# %%
bond = pd.read_csv('data/jamesbond.csv', index_col='Film')
bond.sort_index(inplace=True)
bond.head()
# Out:
#                       Year           Actor         Director  Box Office  \
# Film
# A View to a Kill      1985     Roger Moore        John Glen       275.2
# Casino Royale         2006    Daniel Craig  Martin Campbell       581.5
# Casino Royale         1967     David Niven       Ken Hughes       315.0
# Diamonds Are Forever  1971    Sean Connery     Guy Hamilton       442.5
# Die Another Day       2002  Pierce Brosnan     Lee Tamahori       465.4
#
#                       Budget  Bond Actor Salary
# Film
# A View to a Kill        54.5                9.1
# Casino Royale          145.3                3.3
# Casino Royale           85.0                NaN
# Diamonds Are Forever    34.7                5.8
# Die Another Day        154.2               17.9

# %%
columns = ['Box Office','Budget','Bond Actor Salary']

# %%
# use a for loop to apply to multiple series
for col in columns:
    bond[col] = bond[col].apply(convert_to_strings_and_add_to_millions)
    
bond.head()
# Out:
#                       Year           Actor         Director     Box Office  \
# Film
# A View to a Kill      1985     Roger Moore        John Glen  275.2 million
# Casino Royale         2006    Daniel Craig  Martin Campbell  581.5 million
# Casino Royale         1967     David Niven       Ken Hughes  315.0 million
# Diamonds Are Forever  1971    Sean Connery     Guy Hamilton  442.5 million
# Die Another Day       2002  Pierce Brosnan     Lee Tamahori  465.4 million
#
#                              Budget Bond Actor Salary
# Film
# A View to a Kill       54.5 million       9.1 million
# Casino Royale         145.3 million       3.3 million
# Casino Royale          85.0 million       nan million
# Diamonds Are Forever   34.7 million       5.8 million
# Die Another Day       154.2 million      17.9 million

# %% [markdown]
# ## copy() method

# %%
bond = pd.read_csv('data/jamesbond.csv', index_col='Film')
bond.sort_index(inplace=True)
bond.head()
# Out:
#                       Year           Actor         Director  Box Office  \
# Film
# A View to a Kill      1985     Roger Moore        John Glen       275.2
# Casino Royale         2006    Daniel Craig  Martin Campbell       581.5
# Casino Royale         1967     David Niven       Ken Hughes       315.0
# Diamonds Are Forever  1971    Sean Connery     Guy Hamilton       442.5
# Die Another Day       2002  Pierce Brosnan     Lee Tamahori       465.4
#
#                       Budget  Bond Actor Salary
# Film
# A View to a Kill        54.5                9.1
# Casino Royale          145.3                3.3
# Casino Royale           85.0                NaN
# Diamonds Are Forever    34.7                5.8
# Die Another Day        154.2               17.9

# %%
directors = bond['Director']

# %%
directors.head()
# Out:
# Film
# A View to a Kill              John Glen
# Casino Royale           Martin Campbell
# Casino Royale                Ken Hughes
# Diamonds Are Forever       Guy Hamilton
# Die Another Day            Lee Tamahori
# Name: Director, dtype: object

# %%
directors["A View to a Kill"] = "Mister John Glen"
# Out:
# /Users/simonbaier/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
directors.head()
# Out:
# Film
# A View to a Kill        Mister John Glen
# Casino Royale            Martin Campbell
# Casino Royale                 Ken Hughes
# Diamonds Are Forever        Guy Hamilton
# Die Another Day             Lee Tamahori
# Name: Director, dtype: object

# %%
bond.head()
# Out:
#                       Year           Actor          Director  Box Office  \
# Film
# A View to a Kill      1985     Roger Moore  Mister John Glen       275.2
# Casino Royale         2006    Daniel Craig   Martin Campbell       581.5
# Casino Royale         1967     David Niven        Ken Hughes       315.0
# Diamonds Are Forever  1971    Sean Connery      Guy Hamilton       442.5
# Die Another Day       2002  Pierce Brosnan      Lee Tamahori       465.4
#
#                       Budget  Bond Actor Salary
# Film
# A View to a Kill        54.5                9.1
# Casino Royale          145.3                3.3
# Casino Royale           85.0                NaN
# Diamonds Are Forever    34.7                5.8
# Die Another Day        154.2               17.9

# %%
# using .copy() method will avoid affecting the original df

# %%
bond = pd.read_csv('data/jamesbond.csv', index_col='Film')
bond.sort_index(inplace=True)
bond.head()
# Out:
#                       Year           Actor         Director  Box Office  \
# Film
# A View to a Kill      1985     Roger Moore        John Glen       275.2
# Casino Royale         2006    Daniel Craig  Martin Campbell       581.5
# Casino Royale         1967     David Niven       Ken Hughes       315.0
# Diamonds Are Forever  1971    Sean Connery     Guy Hamilton       442.5
# Die Another Day       2002  Pierce Brosnan     Lee Tamahori       465.4
#
#                       Budget  Bond Actor Salary
# Film
# A View to a Kill        54.5                9.1
# Casino Royale          145.3                3.3
# Casino Royale           85.0                NaN
# Diamonds Are Forever    34.7                5.8
# Die Another Day        154.2               17.9

# %%
directors = bond["Director"].copy()  # creates a new series not linked to the original df
directors['A View to a Kill'] = 'Mr John Glen'
directors.head()
# Out:
# Film
# A View to a Kill           Mr John Glen
# Casino Royale           Martin Campbell
# Casino Royale                Ken Hughes
# Diamonds Are Forever       Guy Hamilton
# Die Another Day            Lee Tamahori
# Name: Director, dtype: object

# %%
bond.head()  # Note that John Glen not changed in original this time
# Out:
#                       Year           Actor         Director  Box Office  \
# Film
# A View to a Kill      1985     Roger Moore        John Glen       275.2
# Casino Royale         2006    Daniel Craig  Martin Campbell       581.5
# Casino Royale         1967     David Niven       Ken Hughes       315.0
# Diamonds Are Forever  1971    Sean Connery     Guy Hamilton       442.5
# Die Another Day       2002  Pierce Brosnan     Lee Tamahori       465.4
#
#                       Budget  Bond Actor Salary
# Film
# A View to a Kill        54.5                9.1
# Casino Royale          145.3                3.3
# Casino Royale           85.0                NaN
# Diamonds Are Forever    34.7                5.8
# Die Another Day        154.2               17.9
